# %% [markdown]
# # Prebuilt Agents
#
# ![Generic Agent Architecture](images/generic-agent-architecture.png)
#
# ## ReAct (a generic agent architecture)
#
# - **act** - take an action
# - **observe** - grab the response from the action
# - **reason** - analyze the response and determine what to do next

# %% [markdown]
# ## Low Level APIs
#
# ### define tools

# %%
import requests
import yfinance as yf
from pprint import pformat

def lookup_stock_symbol(company_name: str) -> str:
    """
    Converts a company name to its stock symbol using a financial API.

    Parameters:
        company_name (str): The full company name (e.g., 'Tesla').

    Returns:
        str: The stock symbol (e.g., 'TSLA') or an error message.
    """
    api_url = "https://www.alphavantage.co/query"
    params = {
        "function": "SYMBOL_SEARCH",
        "keywords": company_name,
        "apikey": "your_alphavantage_api_key"
    }
    
    response = requests.get(api_url, params=params)
    data = response.json()
    
    if "bestMatches" in data and data["bestMatches"]:
        return data["bestMatches"][0]["1. symbol"]
    else:
        return f"Symbol not found for {company_name}."


def fetch_stock_data_raw(stock_symbol: str) -> dict:
    """
    Fetches comprehensive stock data for a given symbol and returns it as a combined dictionary.

    Parameters:
        stock_symbol (str): The stock ticker symbol (e.g., 'TSLA').
        period (str): The period to analyze (e.g., '1mo', '3mo', '1y').

    Returns:
        dict: A dictionary combining general stock info and historical market data.
    """
    period = "1mo"
    try:
        stock = yf.Ticker(stock_symbol)

        # Retrieve general stock info and historical market data
        stock_info = stock.info  # Basic company and stock data
        stock_history = stock.history(period=period).to_dict()  # Historical OHLCV data

        # Combine both into a single dictionary
        combined_data = {
            "stock_symbol": stock_symbol,
            "info": stock_info,
            "history": stock_history
        }

        return pformat(combined_data)

    except Exception as e:
        return {"error": f"Error fetching stock data for {stock_symbol}: {str(e)}"}

# %% [markdown]
# ### Binding tools to the LLM

# %%
from helper import get_openai_api_key
openai_api_key = get_openai_api_key()

import os

os.environ["OPENAI_API_KEY"] = get_openai_api_key()

# %%
from langchain_core.tools import Tool
from langchain_openai import ChatOpenAI

# Create tool bindings with additional attributes
lookup_stock = Tool.from_function(
    func=lookup_stock_symbol,
    name="lookup_stock_symbol",
    description="Converts a company name to its stock symbol using a financial API.",
    return_direct=False  # Return result to be processed by LLM
)

fetch_stock = Tool.from_function(
    func=fetch_stock_data_raw,
    name="fetch_stock_data_raw",
    description="Fetches comprehensive stock data including general info and historical market data for a given stock symbol.",
    return_direct=False
)

toolbox = [lookup_stock, fetch_stock]

# OPENAI_API_KEY environment variable must be set
simple_llm = ChatOpenAI(model="gpt-4o-mini")
llm_with_tools = simple_llm.bind_tools(toolbox)

# %% [markdown]
# ### Defining Agent's node

# %%
from langchain_core.messages import HumanMessage, SystemMessage
from langgraph.graph import MessagesState

# System message
assistant_system_message = SystemMessage(content=("""
You are a friendly, conversational financial assistant.

Your role is to help people understand how companies are doing financially — even if they don’t know much about finance. You can explain things clearly, naturally, and in a relaxed tone, like a person chatting with a curious friend.

You have access to tools that fetch financial data: stock prices, revenue, profit, analyst sentiment, etc. Use this data to understand the situation — but never overwhelm the user with too many numbers or technical terms.

---

### How to respond:

- Your **first reply should always be short and natural**, like the beginning of a real conversation — no long summaries, no number tables, no formal tone.
- Talk like a person. Say things like: “the stock is up a bit today,” “they’re still making money, but growth has slowed,” or “analysts seem cautious right now.”
- **Avoid listing more than one or two numbers** unless the user explicitly asks for detailed data.
- Never answer with a bullet list of metrics or a financial report format.
- Focus on **what the data means**, not just what it is. Translate financial figures into plain English.
- If the user wants more detail, you can go deeper — but only when they ask.

---

Your job is to make financial information feel easy, human, and open-ended — never robotic or overwhelming.
"""))

# Node
def assistant(state: MessagesState):
   return {"messages": [llm_with_tools.invoke([assistant_system_message] + state["messages"])]}
# Out:
# c:\Users\aziz_\Documents\Projects\langgraph-advanced\.venv-1\Lib\site-packages\langgraph\cache\base\__init__.py:8: LangChainPendingDeprecationWarning: The default value of `allowed_objects` will change in a future version. Pass an explicit value (e.g., allowed_objects='messages' or allowed_objects='core') to suppress this warning.
#   from langgraph.checkpoint.serde.jsonplus import JsonPlusSerializer

# %% [markdown]
# ### Defining Graph

# %%
from langgraph.graph import START, StateGraph
from langgraph.prebuilt import tools_condition
from langgraph.prebuilt import ToolNode
from IPython.display import Image, display

# Graph
builder = StateGraph(MessagesState)

# Define nodes: these do the work
builder.add_node("assistant", assistant)
builder.add_node("tools", ToolNode(toolbox))

# Define edges: these determine how the control flow moves
builder.add_edge(START, "assistant")
builder.add_conditional_edges(
    "assistant",
    # If the latest message (result) from assistant is a tool call -> tools_condition routes to tools
    # If the latest message (result) from assistant is a not a tool call -> tools_condition routes to END
    tools_condition,
)
builder.add_edge("tools", "assistant")
react_graph = builder.compile()

# Show
display(Image(react_graph.get_graph(xray=True).draw_mermaid_png()))

# %%
messages = react_graph.invoke({"messages": [HumanMessage(content="What’s the current financial state of Tesla?")]})
for message in messages['messages']:
    message.pretty_print()
# Out:
# c:\Users\aziz_\Documents\Projects\langgraph-advanced\.venv-1\Lib\site-packages\yfinance\scrapers\quote.py:702: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   start = pd.Timestamp.utcnow().floor("D") - datetime.timedelta(days=365 // 2)
# c:\Users\aziz_\Documents\Projects\langgraph-advanced\.venv-1\Lib\site-packages\yfinance\scrapers\quote.py:704: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   end = pd.Timestamp.utcnow().ceil("D")
# ================================ Human Message =================================
#
# What’s the current financial state of Tesla?
# ================================== Ai Message ==================================
# Tool Calls:
#   lookup_stock_symbol (call_gop9a7j6DQDO1ogtAibyjOqm)
#  Call ID: call_gop9a7j6DQDO1ogtAibyjOqm
#   Args:
#     __arg1: Tesla
# ================================= Tool Message =================================
# Name: lookup_stock_symbol
#
# 0R0X.LON
# ================================== Ai Message ==================================
# Tool Calls:
#   fetch_stock_data_raw (call_nBUY6RCtsDWWWj6REl8VNQcg)
#  Call ID: call_nBUY6RCtsDWWWj6REl8VNQcg
#   Args:
#     __arg1: 0R0X.LON
# ================================= Tool Message =================================
# Name: fetch_stock_data_raw
#
# {"error": "Error fetching stock data for 0R0X.LON: HTTP Error 404: "}
# ================================== Ai Message ==================================
# Tool Calls:
#   lookup_stock_symbol (call_z1U74VEh8IHUl4rQymvDVQzA)
#  Call ID: call_z1U74VEh8IHUl4rQymvDVQzA
#   Args:
#     __arg1: TSLA
# ================================= Tool Message =================================
# Name: lookup_stock_symbol
#
# TSLA
# ================================== Ai Message ==================================
# Tool Calls:
#   fetch_stock_data_raw (call_OZv9kiEsmfh7CH3Ut2x97KOd)
#  Call ID: call_OZv9kiEsmfh7CH3Ut2x97KOd
#   Args:
#     __arg1: TSLA
# ================================= Tool Message =================================
# Name: fetch_stock_data_raw
#
# {'history': {'Close': {Timestamp('2026-04-09 00:00:00-0400', tz='America/New_York'): 345.6199951171875,
#                        Timestamp('2026-04-10 00:00:00-0400', tz='America/New_York'): 348.95001220703125,
#                        Timestamp('2026-04-13 00:00:00-0400', tz='America/New_York'): 352.4200134277344,
#                        Timestamp('2026-04-14 00:00:00-0400', tz='America/New_York'): 364.20001220703125,
#                        Timestamp('2026-04-15 00:00:00-0400', tz='America/New_York'): 391.95001220703125,
#                        Timestamp('2026-04-16 00:00:00-0400', tz='America/New_York'): 388.8999938964844,
#                        Timestamp('2026-04-17 00:00:00-0400', tz='America/New_York'): 400.6199951171875,
#                        Timestamp('2026-04-20 00:00:00-0400', tz='America/New_York'): 392.5,
#                        Timestamp('2026-04-21 00:00:00-0400', tz='America/New_York'): 386.4200134277344,
#                        Timestamp('2026-04-22 00:00:00-0400', tz='America/New_York'): 387.510009765625,
#                        Timestamp('2026-04-23 00:00:00-0400', tz='America/New_York'): 373.7200012207031,
#                        Timestamp('2026-04-24 00:00:00-0400', tz='America/New_York'): 376.29998779296875,
#                        Timestamp('2026-04-27 00:00:00-0400', tz='America/New_York'): 378.6700134277344,
#                        Timestamp('2026-04-28 00:00:00-0400', tz='America/New_York'): 376.0199890136719,
#                        Timestamp('2026-04-29 00:00:00-0400', tz='America/New_York'): 372.79998779296875,
#                        Timestamp('2026-04-30 00:00:00-0400', tz='America/New_York'): 381.6300048828125,
#                        Timestamp('2026-05-01 00:00:00-0400', tz='America/New_York'): 390.82000732421875,
#                        Timestamp('2026-05-04 00:00:00-0400', tz='America/New_York'): 392.510009765625,
#                        Timestamp('2026-05-05 00:00:00-0400', tz='America/New_York'): 389.3699951171875,
#                        Timestamp('2026-05-06 00:00:00-0400', tz='America/New_York'): 398.7300109863281,
#                        Timestamp('2026-05-07 00:00:00-0400', tz='America/New_York'): 411.7900085449219,
#                        Timestamp('2026-05-08 00:00:00-0400', tz='America/New_York'): 428.3500061035156},
#              'Dividends': {Timestamp('2026-04-09 00:00:00-0400', tz='America/New_York'): 0.0,
#                            Timestamp('2026-04-10 00:00:00-0400', tz='America/New_York'): 0.0,
#                            Timestamp('2026-04-13 00:00:00-0400', tz='America/New_York'): 0.0,
#                            Timestamp('2026-04-14 00:00:00-0400', tz='America/New_York'): 0.0,
#                            Timestamp('2026-04-15 00:00:00-0400', tz='America/New_York'): 0.0,
#                            Timestamp('2026-04-16 00:00:00-0400', tz='America/New_York'): 0.0,
#                            Timestamp('2026-04-17 00:00:00-0400', tz='America/New_York'): 0.0,
#                            Timestamp('2026-04-20 00:00:00-0400', tz='America/New_York'): 0.0,
#                            Timestamp('2026-04-21 00:00:00-0400', tz='America/New_York'): 0.0,
#                            Timestamp('2026-04-22 00:00:00-0400', tz='America/New_York'): 0.0,
#                            Timestamp('2026-04-23 00:00:00-0400', tz='America/New_York'): 0.0,
#                            Timestamp('2026-04-24 00:00:00-0400', tz='America/New_York'): 0.0,
#                            Timestamp('2026-04-27 00:00:00-0400', tz='America/New_York'): 0.0,
#                            Timestamp('2026-04-28 00:00:00-0400', tz='America/New_York'): 0.0,
#                            Timestamp('2026-04-29 00:00:00-0400', tz='America/New_York'): 0.0,
#                            Timestamp('2026-04-30 00:00:00-0400', tz='America/New_York'): 0.0,
#                            Timestamp('2026-05-01 00:00:00-0400', tz='America/New_York'): 0.0,
#                            Timestamp('2026-05-04 00:00:00-0400', tz='America/New_York'): 0.0,
#                            Timestamp('2026-05-05 00:00:00-0400', tz='America/New_York'): 0.0,
#                            Timestamp('2026-05-06 00:00:00-0400', tz='America/New_York'): 0.0,
#                            Timestamp('2026-05-07 00:00:00-0400', tz='America/New_York'): 0.0,
#                            Timestamp('2026-05-08 00:00:00-0400', tz='America/New_York'): 0.0},
#              'High': {Timestamp('2026-04-09 00:00:00-0400', tz='America/New_York'): 348.8800048828125,
#                       Timestamp('2026-04-10 00:00:00-0400', tz='America/New_York'): 350.3599853515625,
#                       Timestamp('2026-04-13 00:00:00-0400', tz='America/New_York'): 356.3500061035156,
#                       Timestamp('2026-04-14 00:00:00-0400', tz='America/New_York'): 367.6300048828125,
#                       Timestamp('2026-04-15 00:00:00-0400', tz='America/New_York'): 394.6499938964844,
#                       Timestamp('2026-04-16 00:00:00-0400', tz='America/New_York'): 394.05999755859375,
#                       Timestamp('2026-04-17 00:00:00-0400', tz='America/New_York'): 409.2799987792969,
#                       Timestamp('2026-04-20 00:00:00-0400', tz='America/New_York'): 406.79998779296875,
#                       Timestamp('2026-04-21 00:00:00-0400', tz='America/New_York'): 393.95001220703125,
#                       Timestamp('2026-04-22 00:00:00-0400', tz='America/New_York'): 393.010009765625,
#                       Timestamp('2026-04-23 00:00:00-0400', tz='America/New_York'): 386.0,
#                       Timestamp('2026-04-24 00:00:00-0400', tz='America/New_York'): 382.760009765625,
#                       Timestamp('2026-04-27 00:00:00-0400', tz='America/New_York'): 380.7799987792969,
#                       Timestamp('2026-04-28 00:00:00-0400', tz='America/New_York'): 382.2900085449219,
#                       Timestamp('2026-04-29 00:00:00-0400', tz='America/New_York'): 376.3999938964844,
#                       Timestamp('2026-04-30 00:00:00-0400', tz='America/New_York'): 384.75,
#                       Timestamp('2026-05-01 00:00:00-0400', tz='America/New_York'): 397.82000732421875,
#                       Timestamp('2026-05-04 00:00:00-0400', tz='America/New_York'): 394.6400146484375,
#                       Timestamp('2026-05-05 00:00:00-0400', tz='America/New_York'): 402.1199951171875,
#                       Timestamp('2026-05-06 00:00:00-0400', tz='America/New_York'): 401.67999267578125,
#                       Timestamp('2026-05-07 00:00:00-0400', tz='America/New_York'): 415.8299865722656,
#                       Timestamp('2026-05-08 00:00:00-0400', tz='America/New_York'): 431.20001220703125},
#              'Low': {Timestamp('2026-04-09 00:00:00-0400', tz='America/New_York'): 337.25,
#                      Timestamp('2026-04-10 00:00:00-0400', tz='America/New_York'): 342.739990234375,
#                      Timestamp('2026-04-13 00:00:00-0400', tz='America/New_York'): 348.57000732421875,
#                      Timestamp('2026-04-14 00:00:00-0400', tz='America/New_York'): 354.7699890136719,
#                      Timestamp('2026-04-15 00:00:00-0400', tz='America/New_York'): 362.5,
#                      Timestamp('2026-04-16 00:00:00-0400', tz='America/New_York'): 381.79998779296875,
#                      Timestamp('2026-04-17 00:00:00-0400', tz='America/New_York'): 391.6499938964844,
#                      Timestamp('2026-04-20 00:00:00-0400', tz='America/New_York'): 388.3299865722656,
#                      Timestamp('2026-04-21 00:00:00-0400', tz='America/New_York'): 385.2200012207031,
#                      Timestamp('2026-04-22 00:00:00-0400', tz='America/New_York'): 385.29998779296875,
#                      Timestamp('2026-04-23 00:00:00-0400', tz='America/New_York'): 368.3900146484375,
#                      Timestamp('2026-04-24 00:00:00-0400', tz='America/New_York'): 370.7300109863281,
#                      Timestamp('2026-04-27 00:00:00-0400', tz='America/New_York'): 364.0199890136719,
#                      Timestamp('2026-04-28 00:00:00-0400', tz='America/New_York'): 372.5400085449219,
#                      Timestamp('2026-04-29 00:00:00-0400', tz='America/New_York'): 370.0400085449219,
#                      Timestamp('2026-04-30 00:00:00-0400', tz='America/New_York'): 368.1700134277344,
#                      Timestamp('2026-05-01 00:00:00-0400', tz='America/New_York'): 378.79998779296875,
#                      Timestamp('2026-05-04 00:00:00-0400', tz='America/New_York'): 384.79998779296875,
#                      Timestamp('2026-05-05 00:00:00-0400', tz='America/New_York'): 389.0,
#                      Timestamp('2026-05-06 00:00:00-0400', tz='America/New_York'): 384.0199890136719,
#                      Timestamp('2026-05-07 00:00:00-0400', tz='America/New_York'): 402.1199951171875,
#                      Timestamp('2026-05-08 00:00:00-0400', tz='America/New_York'): 416.3900146484375},
#              'Open': {Timestamp('2026-04-09 00:00:00-0400', tz='America/New_York'): 343.1499938964844,
#                       Timestamp('2026-04-10 00:00:00-0400', tz='America/New_York'): 346.2900085449219,
#                       Timestamp('2026-04-13 00:00:00-0400', tz='America/New_York'): 350.07000732421875,
#                       Timestamp('2026-04-14 00:00:00-0400', tz='America/New_York'): 357.6700134277344,
#                       Timestamp('2026-04-15 00:00:00-0400', tz='America/New_York'): 366.8299865722656,
#                       Timestamp('2026-04-16 00:00:00-0400', tz='America/New_York'): 393.80999755859375,
#                       Timestamp('2026-04-17 00:00:00-0400', tz='America/New_York'): 395.9200134277344,
#                       Timestamp('2026-04-20 00:00:00-0400', tz='America/New_York'): 402.5799865722656,
#                       Timestamp('2026-04-21 00:00:00-0400', tz='America/New_York'): 393.0,
#                       Timestamp('2026-04-22 00:00:00-0400', tz='America/New_York'): 387.57000732421875,
#                       Timestamp('2026-04-23 00:00:00-0400', tz='America/New_York'): 375.2799987792969,
#                       Timestamp('2026-04-24 00:00:00-0400', tz='America/New_York'): 373.5,
#                       Timestamp('2026-04-27 00:00:00-0400', tz='America/New_York'): 372.0899963378906,
#                       Timestamp('2026-04-28 00:00:00-0400', tz='America/New_York'): 374.67999267578125,
#                       Timestamp('2026-04-29 00:00:00-0400', tz='America/New_York'): 375.3999938964844,
#                       Timestamp('2026-04-30 00:00:00-0400', tz='America/New_York'): 372.75,
#                       Timestamp('2026-05-01 00:00:00-0400', tz='America/New_York'): 382.489990234375,
#                       Timestamp('2026-05-04 00:00:00-0400', tz='America/New_York'): 390.2300109863281,
#                       Timestamp('2026-05-05 00:00:00-0400', tz='America/New_York'): 395.19000244140625,
#                       Timestamp('2026-05-06 00:00:00-0400', tz='America/New_York'): 386.25,
#                       Timestamp('2026-05-07 00:00:00-0400', tz='America/New_York'): 407.4800109863281,
#                       Timestamp('2026-05-08 00:00:00-0400', tz='America/New_York'): 416.4800109863281},
#              'Stock Splits': {Timestamp('2026-04-09 00:00:00-0400', tz='America/New_York'): 0.0,
#                               Timestamp('2026-04-10 00:00:00-0400', tz='America/New_York'): 0.0,
#                               Timestamp('2026-04-13 00:00:00-0400', tz='America/New_York'): 0.0,
#                               Timestamp('2026-04-14 00:00:00-0400', tz='America/New_York'): 0.0,
#                               Timestamp('2026-04-15 00:00:00-0400', tz='America/New_York'): 0.0,
#                               Timestamp('2026-04-16 00:00:00-0400', tz='America/New_York'): 0.0,
#                               Timestamp('2026-04-17 00:00:00-0400', tz='America/New_York'): 0.0,
#                               Timestamp('2026-04-20 00:00:00-0400', tz='America/New_York'): 0.0,
#                               Timestamp('2026-04-21 00:00:00-0400', tz='America/New_York'): 0.0,
#                               Timestamp('2026-04-22 00:00:00-0400', tz='America/New_York'): 0.0,
#                               Timestamp('2026-04-23 00:00:00-0400', tz='America/New_York'): 0.0,
#                               Timestamp('2026-04-24 00:00:00-0400', tz='America/New_York'): 0.0,
#                               Timestamp('2026-04-27 00:00:00-0400', tz='America/New_York'): 0.0,
#                               Timestamp('2026-04-28 00:00:00-0400', tz='America/New_York'): 0.0,
#                               Timestamp('2026-04-29 00:00:00-0400', tz='America/New_York'): 0.0,
#                               Timestamp('2026-04-30 00:00:00-0400', tz='America/New_York'): 0.0,
#                               Timestamp('2026-05-01 00:00:00-0400', tz='America/New_York'): 0.0,
#                               Timestamp('2026-05-04 00:00:00-0400', tz='America/New_York'): 0.0,
#                               Timestamp('2026-05-05 00:00:00-0400', tz='America/New_York'): 0.0,
#                               Timestamp('2026-05-06 00:00:00-0400', tz='America/New_York'): 0.0,
#                               Timestamp('2026-05-07 00:00:00-0400', tz='America/New_York'): 0.0,
#                               Timestamp('2026-05-08 00:00:00-0400', tz='America/New_York'): 0.0},
#              'Volume': {Timestamp('2026-04-09 00:00:00-0400', tz='America/New_York'): 62164000,
#                         Timestamp('2026-04-10 00:00:00-0400', tz='America/New_York'): 51336000,
#                         Timestamp('2026-04-13 00:00:00-0400', tz='America/New_York'): 53617500,
#                         Timestamp('2026-04-14 00:00:00-0400', tz='America/New_York'): 59979600,
#                         Timestamp('2026-04-15 00:00:00-0400', tz='America/New_York'): 113810400,
#                         Timestamp('2026-04-16 00:00:00-0400', tz='America/New_York'): 63515100,
#                         Timestamp('2026-04-17 00:00:00-0400', tz='America/New_York'): 90640000,
#                         Timestamp('2026-04-20 00:00:00-0400', tz='America/New_York'): 64603900,
#                         Timestamp('2026-04-21 00:00:00-0400', tz='America/New_York'): 50530600,
#                         Timestamp('2026-04-22 00:00:00-0400', tz='America/New_York'): 62362800,
#                         Timestamp('2026-04-23 00:00:00-0400', tz='America/New_York'): 93969500,
#                         Timestamp('2026-04-24 00:00:00-0400', tz='America/New_York'): 62893300,
#                         Timestamp('2026-04-27 00:00:00-0400', tz='America/New_York'): 66735800,
#                         Timestamp('2026-04-28 00:00:00-0400', tz='America/New_York'): 50864400,
#                         Timestamp('2026-04-29 00:00:00-0400', tz='America/New_York'): 45384800,
#                         Timestamp('2026-04-30 00:00:00-0400', tz='America/New_York'): 51076000,
#                         Timestamp('2026-05-01 00:00:00-0400', tz='America/New_York'): 65338300,
#                         Timestamp('2026-05-04 00:00:00-0400', tz='America/New_York'): 48765100,
#                         Timestamp('2026-05-05 00:00:00-0400', tz='America/New_York'): 47780600,
#                         Timestamp('2026-05-06 00:00:00-0400', tz='America/New_York'): 53465400,
#                         Timestamp('2026-05-07 00:00:00-0400', tz='America/New_York'): 64294200,
#                         Timestamp('2026-05-08 00:00:00-0400', tz='America/New_York'): 64880800}},
#  'info': {'52WeekChange': 0.34540486,
#           'SandP52WeekChange': 0.26603174,
#           'address1': '1 Tesla Road',
#           'allTimeHigh': 498.83,
#           'allTimeLow': 0.998667,
#           'ask': 428.62,
#           'askSize': 2,
#           'auditRisk': 4,
#           'averageAnalystRating': '2.4 - Buy',
#           'averageDailyVolume10Day': 55858540,
#           'averageDailyVolume3Month': 62332293,
#           'averageVolume': 62332293,
#           'averageVolume10days': 55858540,
#           'beta': 1.793,
#           'bid': 427.77,
#           'bidSize': 1,
#           'boardRisk': 10,
#           'bookValue': 21.897,
#           'city': 'Austin',
#           'companyOfficers': [{'age': 54,
#                                'exercisedValue': 0,
#                                'fiscalYear': 2024,
#                                'maxAge': 1,
#                                'name': 'Mr. Elon R. Musk',
#                                'title': 'Co-Founder, Technoking of Tesla, CEO '
#                                         '& Director',
#                                'unexercisedValue': 0,
#                                'yearBorn': 1971},
#                               {'age': 47,
#                                'exercisedValue': 9653338,
#                                'fiscalYear': 2024,
#                                'maxAge': 1,
#                                'name': 'Mr. Vaibhav  Taneja',
#                                'title': 'Chief Financial Officer',
#                                'totalPay': 306846,
#                                'unexercisedValue': 347210016,
#                                'yearBorn': 1978},
#                               {'age': 45,
#                                'exercisedValue': 0,
#                                'fiscalYear': 2024,
#                                'maxAge': 1,
#                                'name': 'Mr. Xiaotong  Zhu',
#                                'title': 'Senior Vice President of APAC & '
#                                         'Global Vehicle Manufacturing',
#                                'totalPay': 518250,
#                                'unexercisedValue': 697024064,
#                                'yearBorn': 1980},
#                               {'exercisedValue': 0,
#                                'fiscalYear': 2024,
#                                'maxAge': 1,
#                                'name': 'Travis  Axelrod',
#                                'title': 'Head of Investor Relations',
#                                'unexercisedValue': 0},
#                               {'exercisedValue': 0,
#                                'fiscalYear': 2024,
#                                'maxAge': 1,
#                                'name': 'Mr. Brandon  Ehrhart',
#                                'title': 'General Counsel & Corporate Secretary',
#                                'unexercisedValue': 0},
#                               {'exercisedValue': 0,
#                                'fiscalYear': 2024,
#                                'maxAge': 1,
#                                'name': 'Mr. Franz  von Holzhausen',
#                                'title': 'Chief Designer',
#                                'unexercisedValue': 0},
#                               {'exercisedValue': 0,
#                                'fiscalYear': 2024,
#                                'maxAge': 1,
#                                'name': 'Ms. Roxanne  Inskip-Kaye',
#                                'title': 'Head of Operations - Electric Vehicle '
#                                         'Business',
#                                'unexercisedValue': 0},
#                               {'age': 62,
#                                'exercisedValue': 0,
#                                'fiscalYear': 2024,
#                                'maxAge': 1,
#                                'name': 'Mr. John  Walker',
#                                'title': 'Vice President of Sales - North '
#                                         'America',
#                                'totalPay': 121550,
#                                'unexercisedValue': 0,
#                                'yearBorn': 1963},
#                               {'exercisedValue': 0,
#                                'fiscalYear': 2024,
#                                'maxAge': 1,
#                                'name': 'Mr. Rodney D. Westmoreland Jr.',
#                                'title': 'Director of Construction Management',
#                                'unexercisedValue': 0},
#                               {'exercisedValue': 0,
#                                'fiscalYear': 2024,
#                                'maxAge': 1,
#                                'name': 'Mr. Lars  Moravy',
#                                'title': 'Vice President of Vehicle Engineering',
#                                'unexercisedValue': 0}],
#           'compensationAsOfEpochDate': 1735603200,
#           'compensationRisk': 10,
#           'corporateActions': [],
#           'country': 'United States',
#           'cryptoTradeable': False,
#           'currency': 'USD',
#           'currentPrice': 428.35,
#           'currentRatio': 2.043,
#           'customPriceAlertConfidence': 'HIGH',
#           'dateShortInterest': 1776211200,
#           'dayHigh': 431.2,
#           'dayLow': 416.39,
#           'debtToEquity': 18.738,
#           'displayName': 'Tesla',
#           'earningsCallTimestampEnd': 1776893400,
#           'earningsCallTimestampStart': 1776893400,
#           'earningsGrowth': 0.083,
#           'earningsQuarterlyGrowth': 0.166,
#           'earningsTimestamp': 1776888000,
#           'earningsTimestampEnd': 1784750400,
#           'earningsTimestampStart': 1784750400,
#           'ebitda': 11093999616,
#           'ebitdaMargins': 0.11334,
#           'enterpriseToEbitda': 142.473,
#           'enterpriseToRevenue': 16.148,
#           'enterpriseValue': 1580597379072,
#           'epsCurrentYear': 2.05482,
#           'epsForward': 2.53536,
#           'epsTrailingTwelveMonths': 1.07,
#           'esgPopulated': False,
#           'exchange': 'NMS',
#           'exchangeDataDelayedBy': 0,
#           'exchangeTimezoneName': 'America/New_York',
#           'exchangeTimezoneShortName': 'EDT',
#           'executiveTeam': [],
#           'fiftyDayAverage': 383.1894,
#           'fiftyDayAverageChange': 45.160614,
#           'fiftyDayAverageChangePercent': 0.11785455,
#           'fiftyTwoWeekChangePercent': 34.540485,
#           'fiftyTwoWeekHigh': 498.83,
#           'fiftyTwoWeekHighChange': -70.47998,
#           'fiftyTwoWeekHighChangePercent': -0.14129059,
#           'fiftyTwoWeekLow': 273.21,
#           'fiftyTwoWeekLowChange': 155.14001,
#           'fiftyTwoWeekLowChangePercent': 0.56784165,
#           'fiftyTwoWeekRange': '273.21 - 498.83',
#           'financialCurrency': 'USD',
#           'firstTradeDateMilliseconds': 1277818200000,
#           'floatShares': 2815929087,
#           'forwardEps': 2.53536,
#           'forwardPE': 168.95036,
#           'freeCashflow': 5251999744,
#           'fullExchangeName': 'NasdaqGS',
#           'fullTimeEmployees': 134785,
#           'gmtOffSetMilliseconds': -14400000,
#           'governanceEpochDate': 1777593600,
#           'grossMargins': 0.19065,
#           'grossProfits': 18660999168,
#           'hasPrePostMarketData': True,
#           'heldPercentInsiders': 0.11115,
#           'heldPercentInstitutions': 0.46085,
#           'impliedSharesOutstanding': 3755723871,
#           'industry': 'Auto Manufacturers',
#           'industryDisp': 'Auto Manufacturers',
#           'industryKey': 'auto-manufacturers',
#           'isEarningsDateEstimate': True,
#           'language': 'en-US',
#           'lastFiscalYearEnd': 1767139200,
#           'lastSplitDate': 1661385600,
#           'lastSplitFactor': '3:1',
#           'longBusinessSummary': 'Tesla, Inc. designs, develops, manufactures, '
#                                  'leases, and sells electric vehicles, and '
#                                  'energy generation and storage systems in the '
#                                  'United States, China, and internationally. '
#                                  'The company operates in two segments, '
#                                  'Automotive; and Energy Generation and '
#                                  'Storage. The company offers electric '
#                                  'vehicles, as well as sells automotive '
#                                  'regulatory credits; and non-warranty '
#                                  'maintenance services and collision, '
#                                  'automotive insurance services, as well as '
#                                  'part sales and retail merchandise sale. It '
#                                  'also provides sedans and sport utility '
#                                  'vehicles through direct and used vehicle '
#                                  'sales, a network of Tesla Superchargers, and '
#                                  'in-app upgrades; purchase financing and '
#                                  'leasing services; services for electric '
#                                  'vehicles through its company-owned service '
#                                  'locations and Tesla mobile service '
#                                  'technicians; and vehicle limited warranties '
#                                  'and extended service plans. In addition, the '
#                                  'company engages in the design, manufacture, '
#                                  'installation, sale, and leasing of solar '
#                                  'energy generation and energy storage '
#                                  'products, and related services to '
#                                  'residential, commercial, and industrial '
#                                  'customers and utilities through its website, '
#                                  'stores, and galleries, as well as through a '
#                                  'network of channel partners. Further, it '
#                                  'provides services and repairs to its energy '
#                                  'product customers, including under warranty '
#                                  'and extended service plans; and various '
#                                  'financing options to its residential '
#                                  'customers; lithium-ion battery energy '
#                                  'storage products, such as Powerwall and '
#                                  'Megapack; energy generation products, '
#                                  'including solar panels and solar roof; '
#                                  'self-driving development and artificial '
#                                  'intelligence software, vehicle control and '
#                                  'infotainment software, and battery and '
#                                  'powertrain. The company was formerly known '
#                                  'as Tesla Motors, Inc. and changed its name '
#                                  'to Tesla, Inc. in February 2017. Tesla, Inc. '
#                                  'was incorporated in 2003 and is '
#                                  'headquartered in Austin, Texas.',
#           'longName': 'Tesla, Inc.',
#           'market': 'us_market',
#           'marketCap': 1608764358656,
#           'marketState': 'CLOSED',
#           'maxAge': 86400,
#           'messageBoardId': 'finmb_27444752',
#           'mostRecentQuarter': 1774915200,
#           'netIncomeToCommon': 3862000128,
#           'nextFiscalYearEnd': 1798675200,
#           'nonDilutedMarketCap': 1608764320142,
#           'numberOfAnalystOpinions': 41,
#           'open': 417.43,
#           'operatingCashflow': 16528000000,
#           'operatingMargins': 0.04203,
#           'overallRisk': 10,
#           'payoutRatio': 0.0,
#           'pegRatio': 5.9,
#           'phone': '512 516 8177',
#           'postMarketChange': -0.36999512,
#           'postMarketChangePercent': -0.08637682,
#           'postMarketPrice': 427.98,
#           'postMarketTime': 1778284797,
#           'previousClose': 411.81,
#           'priceEpsCurrentYear': 208.46107,
#           'priceHint': 2,
#           'priceToBook': 19.562042,
#           'priceToSalesTrailing12Months': 16.436256,
#           'profitMargins': 0.03946,
#           'quickRatio': 1.43,
#           'quoteSourceName': 'Nasdaq Real Time Price',
#           'quoteType': 'EQUITY',
#           'recommendationKey': 'buy',
#           'recommendationMean': 2.3617,
#           'region': 'US',
#           'regularMarketChange': 16.54,
#           'regularMarketChangePercent': 4.01642,
#           'regularMarketDayHigh': 431.2,
#           'regularMarketDayLow': 416.39,
#           'regularMarketDayRange': '416.39 - 431.2',
#           'regularMarketOpen': 417.43,
#           'regularMarketPreviousClose': 411.81,
#           'regularMarketPrice': 428.35,
#           'regularMarketTime': 1778270400,
#           'regularMarketVolume': 63489555,
#           'returnOnAssets': 0.022330001,
#           'returnOnEquity': 0.04901,
#           'revenueGrowth': 0.158,
#           'revenuePerShare': 30.312,
#           'sector': 'Consumer Cyclical',
#           'sectorDisp': 'Consumer Cyclical',
#           'sectorKey': 'consumer-cyclical',
#           'shareHolderRightsRisk': 9,
#           'sharesOutstanding': 3755723871,
#           'sharesPercentSharesOut': 0.0189,
#           'sharesShort': 71106902,
#           'sharesShortPreviousMonthDate': 1773360000,
#           'sharesShortPriorMonth': 60860404,
#           'shortName': 'Tesla, Inc.',
#           'shortPercentOfFloat': 0.021300001,
#           'shortRatio': 1.07,
#           'sourceInterval': 15,
#           'state': 'TX',
#           'symbol': 'TSLA',
#           'targetHighPrice': 600.0,
#           'targetLowPrice': 123.0,
#           'targetMeanPrice': 412.25366,
#           'targetMedianPrice': 450.0,
#           'totalCash': 44743000064,
#           'totalCashPerShare': 11.913,
#           'totalDebt': 15889999872,
#           'totalRevenue': 97878999040,
#           'tradeable': False,
#           'trailingAnnualDividendRate': 0.0,
#           'trailingAnnualDividendYield': 0.0,
#           'trailingEps': 1.07,
#           'trailingPE': 400.3271,
#           'trailingPegRatio': 5.8981,
#           'triggerable': True,
#           'twoHundredDayAverage': 404.3852,
#           'twoHundredDayAverageChange': 23.964813,
#           'twoHundredDayAverageChangePercent': 0.059262343,
#           'typeDisp': 'Equity',
#           'volume': 63489555,
#           'website': 'https://www.tesla.com',
#           'zip': '78725'},
#  'stock_symbol': 'TSLA'}
# ================================== Ai Message ==================================
#
# Tesla's stock is currently hovering around $428.35, showing some positive momentum today. Overall, the company is doing well financially, with a notable revenue growth of around 15% over the past year. They're still very much profitable, but analysts are showing a bit of caution — their ratings average suggests they’re leaning towards a “buy,” but they also recognize that the stock has been quite high lately.
#
# If you want to dive deeper into any specific area, just let me know!

# %% [markdown]
# ## Using high level API with Prebuilt Agents

# %%
from langchain.agents import create_agent

agent = create_agent(
    model=simple_llm,
    tools=[lookup_stock_symbol, fetch_stock_data_raw]
    #prompt=assistant_system_message
)

display(Image(agent.get_graph(xray=True).draw_mermaid_png()))

# %%
messages = agent.invoke({"messages": [HumanMessage(content="What’s the current financial state of Tesla?")]})
for message in messages['messages']:
    message.pretty_print()
# Out:
# ================================ Human Message =================================
#
# What’s the current financial state of Tesla?
# ================================== Ai Message ==================================
# Tool Calls:
#   lookup_stock_symbol (call_bW2u8KePnIYir10cgecJv6T4)
#  Call ID: call_bW2u8KePnIYir10cgecJv6T4
#   Args:
#     company_name: Tesla
# ================================= Tool Message =================================
# Name: lookup_stock_symbol
#
# 0R0X.LON
# ================================== Ai Message ==================================
# Tool Calls:
#   fetch_stock_data_raw (call_6Z3dHzYY6NbLFe3sW7imgUVK)
#  Call ID: call_6Z3dHzYY6NbLFe3sW7imgUVK
#   Args:
#     stock_symbol: 0R0X.LON
# ================================= Tool Message =================================
# Name: fetch_stock_data_raw
#
# {"error": "Error fetching stock data for 0R0X.LON: HTTP Error 404: "}
# ================================== Ai Message ==================================
# Tool Calls:
#   lookup_stock_symbol (call_m63QP7g6SaJFQA3CwTX7EER9)
#  Call ID: call_m63QP7g6SaJFQA3CwTX7EER9
#   Args:
#     company_name: Tesla, Inc.
# ================================= Tool Message =================================
# Name: lookup_stock_symbol
#
# Symbol not found for Tesla, Inc..
# ================================== Ai Message ==================================
#
# It seems that I'm having trouble retrieving the stock symbol for Tesla, Inc. I will try again to confirm the correct stock symbol before fetching the financial data.
# Tool Calls:
#   lookup_stock_symbol (call_wHDhQ0NZzjvpHN1Mivfir0gB)
#  Call ID: call_wHDhQ0NZzjvpHN1Mivfir0gB
#   Args:
#     company_name: Tesla Inc.
# ================================= Tool Message =================================
# Name: lookup_stock_symbol
#
# TL01.FRK
# ================================== Ai Message ==================================
# Tool Calls:
#   fetch_stock_data_raw (call_sKSdjka3nLFyTnGW54o0HGEj)
#  Call ID: call_sKSdjka3nLFyTnGW54o0HGEj
#   Args:
#     stock_symbol: TL01.FRK
# ================================= Tool Message =================================
# Name: fetch_stock_data_raw
#
# {"error": "Error fetching stock data for TL01.FRK: HTTP Error 404: "}
# ================================== Ai Message ==================================
# Tool Calls:
#   lookup_stock_symbol (call_sA2UTMInRlXacgGhMqAmPvBJ)
#  Call ID: call_sA2UTMInRlXacgGhMqAmPvBJ
#   Args:
#     company_name: Tesla
# ================================= Tool Message =================================
# Name: lookup_stock_symbol
#
# 0R0X.LON
# ================================== Ai Message ==================================
#
# It appears that I'm unable to retrieve the stock symbol for Tesla, Inc. accurately at the moment, and my attempts to fetch the financial data have resulted in errors.
#
# You may want to look up Tesla's stock information directly on a financial news website or a stock market app for the most current details. If there's anything else you'd like me to assist you with, please let me know!

# %%
messages = agent.invoke({"messages": [HumanMessage(content="So, do you think this is a good idea to buy this stock?")]})
for message in messages['messages']:
    message.pretty_print()
# Out:
# ================================ Human Message =================================
#
# So, do you think this is a good idea to buy this stock?
# ================================== Ai Message ==================================
#
# To provide a well-informed opinion on whether it's a good idea to buy a specific stock, I would need to know the name of the company or the stock symbol. Additionally, it would be helpful to look at recent stock data, market trends, and any relevant news regarding the company.
#
# Could you please provide the company name or stock symbol you're considering?

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent_with_memory = create_agent(
    model=simple_llm,
    tools=[lookup_stock_symbol, fetch_stock_data_raw],
    #prompt=assistant_system_message,
    checkpointer=InMemorySaver()
)

display(Image(agent_with_memory.get_graph(xray=True).draw_mermaid_png()))

# %%
config = {"configurable": {"thread_id": "1"}}

messages = agent_with_memory.invoke({"messages": [HumanMessage(content="What’s the current financial state of Tesla?")]}, config)
for message in messages['messages']:
    message.pretty_print()
# Out:
# ================================ Human Message =================================
#
# What’s the current financial state of Tesla?
# ================================== Ai Message ==================================
# Tool Calls:
#   lookup_stock_symbol (call_b58Nn6LKthbtKBugyElcG4Lp)
#  Call ID: call_b58Nn6LKthbtKBugyElcG4Lp
#   Args:
#     company_name: Tesla
# ================================= Tool Message =================================
# Name: lookup_stock_symbol
#
# 0R0X.LON
# ================================== Ai Message ==================================
# Tool Calls:
#   fetch_stock_data_raw (call_lnBBFbnSrLA7rUtcBelmHV7P)
#  Call ID: call_lnBBFbnSrLA7rUtcBelmHV7P
#   Args:
#     stock_symbol: 0R0X.LON
# ================================= Tool Message =================================
# Name: fetch_stock_data_raw
#
# {"error": "Error fetching stock data for 0R0X.LON: HTTP Error 404: "}
# ================================== Ai Message ==================================
# Tool Calls:
#   lookup_stock_symbol (call_ibuiYautDM6qhkEF1lJBelwG)
#  Call ID: call_ibuiYautDM6qhkEF1lJBelwG
#   Args:
#     company_name: Tesla, Inc.
# ================================= Tool Message =================================
# Name: lookup_stock_symbol
#
# Symbol not found for Tesla, Inc..
# ================================== Ai Message ==================================
# Tool Calls:
#   lookup_stock_symbol (call_FgWMYGTc1cRsD1B5cngfT6KT)
#  Call ID: call_FgWMYGTc1cRsD1B5cngfT6KT
#   Args:
#     company_name: Tesla Motors
# ================================= Tool Message =================================
# Name: lookup_stock_symbol
#
# Symbol not found for Tesla Motors.
# ================================== Ai Message ==================================
# Tool Calls:
#   lookup_stock_symbol (call_W16WcWnfXdtks8cQqWIYOqPq)
#  Call ID: call_W16WcWnfXdtks8cQqWIYOqPq
#   Args:
#     company_name: Tesla, Inc.
# ================================= Tool Message =================================
# Name: lookup_stock_symbol
#
# Symbol not found for Tesla, Inc..
# ================================== Ai Message ==================================
# Tool Calls:
#   lookup_stock_symbol (call_P18S5ZptcOT2nqocK6MLpCWR)
#  Call ID: call_P18S5ZptcOT2nqocK6MLpCWR
#   Args:
#     company_name: Tesla Automotive
# ================================= Tool Message =================================
# Name: lookup_stock_symbol
#
# Symbol not found for Tesla Automotive.
# ================================== Ai Message ==================================
# Tool Calls:
#   lookup_stock_symbol (call_bLYoRTHQhwZNtumxa6zJRKop)
#  Call ID: call_bLYoRTHQhwZNtumxa6zJRKop
#   Args:
#     company_name: Tesla
# ================================= Tool Message =================================
# Name: lookup_stock_symbol
#
# 0R0X.LON
# ================================== Ai Message ==================================
# Tool Calls:
#   fetch_stock_data_raw (call_jY2prnrfknjB1daB72XmrmJJ)
#  Call ID: call_jY2prnrfknjB1daB72XmrmJJ
#   Args:
#     stock_symbol: 0R0X.LON
# ================================= Tool Message =================================
# Name: fetch_stock_data_raw
#
# {"error": "Error fetching stock data for 0R0X.LON: HTTP Error 404: "}
# ================================== Ai Message ==================================
#
# I was unable to retrieve the current financial state of Tesla due to issues with finding the correct stock symbol. It appears that the available symbol for Tesla may not be working correctly.
#
# You may want to check financial news websites or stock market platforms for the latest information on Tesla's financial state. If there's anything else you'd like me to help you with, please let me know!

# %%
messages = agent_with_memory.invoke({"messages": [HumanMessage(content="So, do you think this is a good idea to buy this stock?")]}, config)
for message in messages['messages']:
    message.pretty_print()
# Out:
# ================================ Human Message =================================
#
# What’s the current financial state of Tesla?
# ================================== Ai Message ==================================
# Tool Calls:
#   lookup_stock_symbol (call_b58Nn6LKthbtKBugyElcG4Lp)
#  Call ID: call_b58Nn6LKthbtKBugyElcG4Lp
#   Args:
#     company_name: Tesla
# ================================= Tool Message =================================
# Name: lookup_stock_symbol
#
# 0R0X.LON
# ================================== Ai Message ==================================
# Tool Calls:
#   fetch_stock_data_raw (call_lnBBFbnSrLA7rUtcBelmHV7P)
#  Call ID: call_lnBBFbnSrLA7rUtcBelmHV7P
#   Args:
#     stock_symbol: 0R0X.LON
# ================================= Tool Message =================================
# Name: fetch_stock_data_raw
#
# {"error": "Error fetching stock data for 0R0X.LON: HTTP Error 404: "}
# ================================== Ai Message ==================================
# Tool Calls:
#   lookup_stock_symbol (call_ibuiYautDM6qhkEF1lJBelwG)
#  Call ID: call_ibuiYautDM6qhkEF1lJBelwG
#   Args:
#     company_name: Tesla, Inc.
# ================================= Tool Message =================================
# Name: lookup_stock_symbol
#
# Symbol not found for Tesla, Inc..
# ================================== Ai Message ==================================
# Tool Calls:
#   lookup_stock_symbol (call_FgWMYGTc1cRsD1B5cngfT6KT)
#  Call ID: call_FgWMYGTc1cRsD1B5cngfT6KT
#   Args:
#     company_name: Tesla Motors
# ================================= Tool Message =================================
# Name: lookup_stock_symbol
#
# Symbol not found for Tesla Motors.
# ================================== Ai Message ==================================
# Tool Calls:
#   lookup_stock_symbol (call_W16WcWnfXdtks8cQqWIYOqPq)
#  Call ID: call_W16WcWnfXdtks8cQqWIYOqPq
#   Args:
#     company_name: Tesla, Inc.
# ================================= Tool Message =================================
# Name: lookup_stock_symbol
#
# Symbol not found for Tesla, Inc..
# ================================== Ai Message ==================================
# Tool Calls:
#   lookup_stock_symbol (call_P18S5ZptcOT2nqocK6MLpCWR)
#  Call ID: call_P18S5ZptcOT2nqocK6MLpCWR
#   Args:
#     company_name: Tesla Automotive
# ================================= Tool Message =================================
# Name: lookup_stock_symbol
#
# Symbol not found for Tesla Automotive.
# ================================== Ai Message ==================================
# Tool Calls:
#   lookup_stock_symbol (call_bLYoRTHQhwZNtumxa6zJRKop)
#  Call ID: call_bLYoRTHQhwZNtumxa6zJRKop
#   Args:
#     company_name: Tesla
# ================================= Tool Message =================================
# Name: lookup_stock_symbol
#
# 0R0X.LON
# ================================== Ai Message ==================================
# Tool Calls:
#   fetch_stock_data_raw (call_jY2prnrfknjB1daB72XmrmJJ)
#  Call ID: call_jY2prnrfknjB1daB72XmrmJJ
#   Args:
#     stock_symbol: 0R0X.LON
# ================================= Tool Message =================================
# Name: fetch_stock_data_raw
#
# {"error": "Error fetching stock data for 0R0X.LON: HTTP Error 404: "}
# ================================== Ai Message ==================================
#
# I was unable to retrieve the current financial state of Tesla due to issues with finding the correct stock symbol. It appears that the available symbol for Tesla may not be working correctly.
#
# You may want to check financial news websites or stock market platforms for the latest information on Tesla's financial state. If there's anything else you'd like me to help you with, please let me know!
# ================================ Human Message =================================
#
# So, do you think this is a good idea to buy this stock?
# ================================== Ai Message ==================================
#
# I can't provide specific investment advice, including whether to buy or sell a particular stock. However, I can suggest several factors to consider when evaluating whether to invest in a stock like Tesla:
#
# 1. **Company Performance**: Look into Tesla's past performance, revenue growth, profitability, and debt levels.
#
# 2. **Market Conditions**: Consider the overall market conditions and how they might affect Tesla. The automotive industry, especially electric vehicles, is influenced by economic factors, competition, and regulatory changes.
#
# 3. **Technical Analysis**: Many investors use charts and market trends to make decisions. Investigating Tesla's stock price movements and trends could be helpful.
#
# 4. **Long-term Potential**: Evaluate Tesla's long-term strategy, including its growth potential in electric vehicles, energy solutions, and potential new markets.
#
# 5. **Risks**: Understand the risks involved with investing in stocks, especially in a volatile industry like electric vehicles.
#
# 6. **Analyst Opinions**: Research what financial analysts are saying about Tesla. Sometimes, their reports can provide insight into the potential future performance of the stock.
#
# It's always a good idea to consult with a financial advisor to determine the best investment strategy for your individual circumstances.

# %% [markdown]
# ## Visualize an agent graph
#
# https://langchain-ai.github.io/langgraph/agents/overview/#visualize-an-agent-graph

# %% [markdown]
# ## Reference Links
#
# **1. LangGraph Agents: Official Overview**
#
# https://langchain-ai.github.io/langgraph/agents/overview/
#
# → High-level introduction to LangGraph’s agent system, including use cases, architecture, and behavior.
#
#
# **2. LangGraph Agents: Prebuilt Agent Classes & Setup**
#
# https://langchain-ai.github.io/langgraph/agents/agents/
#
# → Documentation on using prebuilt agent classes like AgentExecutorGraph, along with memory, tools, and config options.
#
#
# **3. LangGraph Agents: API Reference**
#
# https://langchain-ai.github.io/langgraph/reference/agents/
#
# → Technical reference for the prebuilt agent API — class signatures, initialization parameters, and helper functions.
